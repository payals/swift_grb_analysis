# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
grb = pd.DataFrame.from_csv('swift_grb.tsv', sep='\t')
grb.head()
# Out:
#           Time [UT] Trigger Number BAT RA (J2000) BAT Dec (J2000)  \
# GRB
# 180205A  04:25:29.3         808625        126.819          11.536
# 180204A    02:36:16         808483        330.123          30.852
# 180115A    04:16:03         805318         12.040         -15.632
# 180113A    02:47:06         804999         19.211          68.682
# 180111A    16:42:06         804692        149.782          48.254
#
#         BAT 90% Error Radius [arcmin] BAT T90 [sec]  \
# GRB
# 180205A                           1.1          15.5
# 180204A                           1.1          1.16
# 180115A                           1.8          40.9
# 180113A                           1.0            64
# 180111A                           1.0          50.6
#
#         BAT Fluence (15-150 keV) [10^-7 erg/cm^2] XRT RA (J2000)  \
# GRB
# 180205A                                        10    08:27:16.72
# 180204A                                       4.8    22:00:31.98
# 180115A                                       7.6    00:48:09.32
# 180113A                                        48            n/a
# 180111A                                       102    09:59:07.12
#
#         XRT Dec (J2000) XRT Time to First Observation [sec]  \
# GRB
# 180205A      11:32:31.6                                 n/a
# 180204A      30:50:16.2                               87.17
# 180115A     -15:37:50.5                              131.07
# 180113A             n/a                                 n/a
# 180111A      48:16:02.7                               87.78
#
#         XRT Early Flux (0.3-10 keV) [10^-11 erg/cm^2/s] UVOT RA (J2000)  \
# GRB
# 180205A                                            95.0     08:27:16.74
# 180204A                                             n/a             n/a
# 180115A                                            35.7     00:48:09.27
# 180113A                                             n/a             n/a
# 180111A                                            57.1      09:59:07.0
#
#         UVOT Dec (J2000) UVOT Time to First Observation [sec] UVOT Magnitude  \
# GRB
# 180205A       11:32:30.9                                  182        V=16.11
# 180204A              n/a                                   92         V>19.0
# 180115A      -15:37:49.9                                  140        V=16.50
# 180113A              n/a                                  n/a            n/a
# 180111A       48:16:03.3                                   98         V>19.3
#
#                               Other Observatory Detections  \
# GRB
# 180205A  KAIT (0.76m), MPG (2.2m), VLT, Fermi (GBM), Sa...
# 180204A                            Fermi (GBM), Konus-Wind
# 180115A              NOT (2.5m), GTC (1.4m), Palomar (60")
# 180113A  Fermi (GBM), Konus-Wind, CALET (GBM), Astrosat...
# 180111A  AGILE, HJT (1.5m), TNT, AbAO (AS-32, 0.7m), CA...
#
#                         Redshift Host Galaxy  \
# GRB
# 180205A  1.409 (VLT: absorption)         NaN
# 180204A                      NaN         NaN
# 180115A              2.487 (GTC)         NaN
# 180113A                      NaN         NaN
# 180111A                      NaN         NaN
#
#                                                   Comments  References
# GRB
# 180205A                                                NaN         NaN
# 180204A                                 UVOT: no detection         NaN
# 180115A                                                NaN         NaN
# 180113A  Due to an observing constraint, Swift will not...         NaN
# 180111A                                                NaN         NaN

# %%
grb = grb.rename(index=str, columns={"Time [UT]": "time", "Host Galaxy": "host_galaxy", 'Trigger Number': "t_no", 
                                     'BAT RA (J2000)': 'bat_ra', 'BAT Dec (J2000)': 'bat_dec',
                                     'BAT 90% Error Radius [arcmin]': 'bat_err_radius',
                                     'BAT Fluence (15-150 keV) [10^-7 erg/cm^2]': 'bat_fluence', 'XRT RA (J2000)': 'xray_ra',
                                     'XRT Dec (J2000)': 'xray_dec', 'XRT Time to First Observation [sec]': 'xray_tto',
                                     'XRT Early Flux (0.3-10 keV) [10^-11 erg/cm^2/s]': 'xray_flux',
                                     'UVOT RA (J2000)': 'uv_ra', 'UVOT Dec (J2000)': 'uv_dec',
                                     'UVOT Time to First Observation [sec]': 'uv_tto', 'UVOT Magnitude': 'uv_mag',
                                     'Other Observatory Detections' : 'other_observatories', 'Redshift': 'redshift',
                                     'Comments': 'comments'})
grb.count()
# Out:
# time                   1188
# t_no                   1188
# bat_ra                 1188
# bat_dec                1188
# bat_err_radius         1188
# BAT T90 [sec]          1188
# bat_fluence            1188
# xray_ra                1188
# xray_dec               1188
# xray_tto               1188
# xray_flux              1188
# uv_ra                  1188
# uv_dec                 1188
# uv_tto                 1188
# uv_mag                 1188
# other_observatories     810
# redshift                353
# host_galaxy              91
# comments                796
# References                0
# dtype: int64

# %%
import re

grb = grb.dropna(subset = ['time'])
if len(i.split(':')) != 3:
    grb.drop(i, inplace=True)
    print(i)
for i in range(len(grb.time)):
    grb.time[i] = str(grb.time[i]).split('.')[0]
# Out:
# /home/payal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pattern = '^\d\d:\d\d:\d\d$'

for i in range(len(grb.time)):
    if not (re.search(pattern, grb.time[i])):   
        grb.time[i] = "null"
# Out:
# /home/payal/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
grb.columns.values
# Out:
# array(['time', 't_no', 'bat_ra', 'bat_dec', 'bat_err_radius',
#        'BAT T90 [sec]', 'bat_fluence', 'xray_ra', 'xray_dec', 'xray_tto',
#        'xray_flux', 'uv_ra', 'uv_dec', 'uv_tto', 'uv_mag',
#        'other_observatories', 'redshift', 'host_galaxy', 'comments',
#        'References'], dtype=object)

# %% [markdown]
# ## Distribution by time

# %%
grb['hour'] = pd.to_datetime(grb['time']).dt.hour

# %%
a = grb.groupby('hour').bat_ra.nunique().reset_index()
# Out:
#     hour  bat_ra
# 0      0      55
# 1      1      68
# 2      2      51
# 3      3      50
# 4      4      58
# 5      5      49
# 6      6      51
# 7      7      58
# 8      8      56
# 9      9      51
# 10    10      45
# 11    11      57
# 12    12      43
# 13    13      47
# 14    14      40
# 15    15      57
# 16    16      33
# 17    17      42
# 18    18      41
# 19    19      46
# 20    20      39
# 21    21      55
# 22    22      50
# 23    23      46

# %%
fig = plt.figure()

hour = a['hour'].tolist()
f = a['bat_ra'].tolist()

plt.plot(hour, f)

plt.show()
