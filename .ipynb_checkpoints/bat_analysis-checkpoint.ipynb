# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn
seaborn.set(style='ticks')

from astropy import units as u
from astropy.coordinates import SkyCoord

# %%
bat = pd.DataFrame.from_csv('grb_bat.tsv', sep='\t')

# %%
bat = bat.rename(index=str, columns={"Time [UT]": "time", 'Trigger Number': "t_no", 
                                     'BAT RA (J2000)': 'bat_ra', 'BAT Dec (J2000)': 'bat_dec'})

# %%
bat = bat.replace("n/a", np.nan)
bat = bat.dropna()

for i in range(len(bat.time)):
    bat.time[i] = str(bat.time[i]).split('.')[0]

# %%
bat.count()
# Out:
# time       1185
# t_no       1185
# bat_ra     1185
# bat_dec    1185
# dtype: int64

# %%
bat['hour'] = pd.to_datetime(bat['time']).dt.hour

a = bat.groupby('hour').t_no.nunique().reset_index()

hour = a['hour'].tolist()
f = a['t_no'].tolist()

# %%
# Bar graph

fig = plt.figure()
 
plt.bar(hour, f)
plt.xlabel('Hour')
plt.ylabel('# Detections')
plt.title('Hourly GRB Detection')

plt.show()

# %%
bat_ra = list(map(float, bat['bat_ra'].tolist()))
bat_dec = list(map(float, bat['bat_dec'].tolist()))



c = SkyCoord(ra=bat_ra*u.degree, dec=bat_dec*u.degree)

# %%
c.ra.hour
# Out:
# array([  8.4546    ,  22.0082    ,   0.80266667, ...,  11.17826667,
#          0.41026667,  10.9862    ])

# %%
c.galactic
# Out:
# <SkyCoord (Galactic): (l, b) in deg
#     [( 213.15252535,  26.44283363), (  84.86601488, -19.10758427),
#      ( 118.97783825, -78.47857395), ..., ( 279.89559782,  24.86781203),
#      ( 119.87728414,   0.13444065), ( 268.66357987,  37.34899783)]>

# %%
c.representation_type = "cartesian"

# %%
type(c)
# Out:
# astropy.coordinates.sky_coordinate.SkyCoord

# %%
c.to_string()
# Out:
# ['126.819 11.536',
#  '330.123 30.852',
#  '12.04 -15.632',
#  '19.211 68.682',
#  '149.782 48.254',
#  '159.585 -53.555',
#  '203.078 62.161',
#  '148.273 35.624',
#  '212.013 -50.5',
#  '293.92 20.597',
#  '98.154 -58.689',
#  '139.387 -30.523',
#  '167.423 -12.599',
#  '186.198 32.503',
#  '163.774 22.461',
#  '278.392 9.118',
#  '249.51 -10.206',
#  '288.096 22.434',
#  '61.683 -2.601',
#  '39.26 15.199',
#  '236.766 -10.064',
#  '34.123 -54.41',
#  '135.635 42.93',
#  '139.15 52.684',
#  '22.08 -11.928',
#  '26.84 30.88',
#  '215.464 -61.997',
#  '167.386 -54.343',
#  '128.659 70.805',
#  '232.221 -28.251',
#  '203.949 -47.088',
#  '254.532 34.985',
#  '276.189 -40.202',
#  '188.713 35.549',
#  '94.375 55',
#  '201.057 -5.527',
#  '187.928 3.664',
#  '143.434 -17.348',
#  '6.404 -64.781',
#  '174.947 -16.312',
#  '238.019 70.111',
#  '58.901 12.169',
#  '150.057 -1.025',
#  '34.322 1.962',
#  '45.782 47.845',
#  '43.122 42.679',
#  '231.851 -38.523',
#  '191.708 18.298',
#  '129.963 -46.585',
#  '165.409 56.479',
#  '7.358 9.225',
#  '342.645 -15.406',
#  '286.901 -16.414',
#  '121.218 -14.017',
#  '4.723 1.277',
#  '90.864 -17.086',
#  '319.488 48.603',
#  '163.429 25.374',
#  '41.543 -55.929',
#  '330.051 26.913',
#  '60.494 -15.121',
#  '79.854 -21.433',
#  '219.824 -25.236',
#  '323.778 -24.406',
#  '283.331 -13.458',
#  '127.483 20.526',
#  '284.229 6.335',
#  '305.662 28.408',
#  '93.087 50.5',
#  '280.539 -30.041',
#  '13.51 9.538',
#  '263.087 -44.765',
#  '127.145 -9.027',
#  '166.544 -46.786',
#  '271.784 11.175',
#  '262.157 -0.058',
#  '332.861 25.186',
#  '152.526 5.021',
#  '341.447 64.006',
#  '19.997 -30.34',
#  '174.382 -45.827',
#  '263.623 -64.755',
#  '332.145 13.75',
#  '61.735 -71.933',
#  '15.232 -17.233',
#  '20.688 -32.541',
#  '267.089 11.642',
#  '204.82 -18.028',
#  '350.841 -47.48',
#  '91.717 -26.801',
#  '245.25 -4.113',
#  '150.658 52.344',
#  '3.857 7.342',
#  '356.904 19.652',
#  '316.221 32.137',
#  '298.83 -67.681',
#  '322.053 -29.612',
#  '179.794 -5.316',
#  '180.776 24.905',
#  '120.198 -44.763',
#  '77.906 -51.447',
#  '128.988 54.366',
#  '142.77 43.125',
#  '332.626 7.467',
#  '245.687 8.313',
#  '103.408 23.289',
#  '112.156 -39.896',
#  '263.127 -0.947',
#  '71.923 -57.261',
#  '256.268 17.334',
#  '295.652 46.4',
#  '301.595 57.585',
#  '162.249 -50.803',
#  '179.274 -29.178',
#  '183.12 -67.664',
#  '80.087 40.039',
#  '280.005 62.387',
#  '171.254 42.345',
#  '288.616 84.298',
#  '221.652 10.002',
#  '212.763 13.485',
#  '98.809 -6.617',
#  '190.502 -61.364',
#  '234.49 63.809',
#  '304.166 -26.965',
#  '235.996 -28.188',
#  '168.107 46.707',
#  '287.414 36.913',
#  '198.238 -56.029',
#  '176.939 -65.142',
#  '330.21 29.667',
#  '348.364 -25.375',
#  '164.417 -70.396',
#  '13.661 -4.952',
#  '234.923 64.532',
#  '149.438 51.197',
#  '103.575 -0.199',
#  '71.122 31.246',
#  '265.857 -46.127',
#  '170.073 56.002',
#  '286.389 -17.249',
#  '280.339 -54.343',
#  '319.482 -60.408',
#  '16.418 -27.341',
#  '120.26 7.646',
#  '33.074 -67.636',
#  '349.37 -40.258',
#  '150.695 3.461',
#  '289.705 -5.39',
#  '122.561 71.128',
#  '146.698 54.018',
#  '15.697 -72.702',
#  '99.42 5.753',
#  '112.766 17.024',
#  '183.821 57.278',
#  '168.71 22.71',
#  '107.311 26.946',
#  '195.034 78.672',
#  '164.217 53.659',
#  '147.603 9.369',
#  '259.851 -18.123',
#  '236.942 -18.539',
#  '311.679 -71.55',
#  '161.967 -24.772',
#  '78.17 -7.037',
#  '225.966 0.08',
#  '150.277 -33.79',
#  '109.08 -23.59',
#  '211.916 20.453',
#  '132.19 -16.34',
#  '20.367 -0.677',
#  '76.808 11.334',
#  '329.363 -20.732',
#  '344.431 8.081',
#  '214.017 -17.665',
#  '93.622 35.529',
#  '65.08 -71.225',
#  '41.19 -43.461',
#  '229.291 35.767',
#  '19.664 -82.762',
#  '299.704 -19.899',
#  '57.169 65.889',
#  '120.947 -61.033',
#  '2.05 -61.68',
#  '56.85 -44.154',
#  '217.139 -59.68',
#  '83.189 -39.125',
#  '38.537 -35.356',
#  '76.188 -6.428',
#  '272.498 61.361',
#  '271.012 -8.289',
#  '349.223 55.812',
#  '337.647 -33.189',
#  '147.426 70.508',
#  '213.613 -64.956',
#  '336.974 64.637',
#  '233.722 10.984',
#  '227.538 -19.64',
#  '319.675 -34.874',
#  '67.428 5.731',
#  '5.677 33.466',
#  '255.265 -63.798',
#  '183.609 25.076',
#  '271.03 -27.243',
#  '221.034 -25.619',
#  '341.913 -57.883',
#  '42.34 9.787',
#  '230.34 68.342',
#  '249.635 -12.05',
#  '291.347 -15.434',
#  '82.961 -5.374',
#  '292.271 33.906',
#  '203.968 -18.32',
#  '97.549 -19.147',
#  '218.297 -35.196',
#  '119.577 -28.281',
#  '278.481 -12.978',
#  '221.624 -35.464',
#  '83.191 -46.96',
#  '194.484 14.309',
#  '187.627 66.794',
#  '111.353 -37.803',
#  '314.713 -53.403',
#  '107.554 -22.466',
#  '140.015 68.436',
#  '7.496 44.29',
#  '327.511 57.519',
#  '288.962 4.195',
#  '49.044 -22.868',
#  '326.481 -27.919',
#  '292.661 4.114',
#  '188.539 6.967',
#  '152.305 -26.646',
#  '221.601 12.264',
#  '190.396 71.839',
#  '216.603 38.541',
#  '311.505 -62.706',
#  '173.658 40.992',
#  '192.625 50.165',
#  '260.447 38.316',
#  '128.173 45.442',
#  '324.99 -61.461',
#  '138.995 55.477',
#  '126.661 63.839',
#  '277.004 86.417',
#  '175.515 36.852',
#  '89.159 -57.969',
#  '244.281 -48.732',
#  '198.787 -12.151',
#  '253.448 34.165',
#  '285.497 47.389',
#  '254.846 55.39',
#  '10.076 -63.181',
#  '160.241 -64.043',
#  '98.394 6.952',
#  '39.261 -33.132',
#  '11.82 -37.62',
#  '39.309 8.064',
#  '10.33 33.98',
#  '289.374 32.529',
#  '131.674 -48.896',
#  '188.044 -10.956',
#  '312.599 36.669',
#  '138.754 33.774',
#  '198.283 8.197',
#  '195.058 32.146',
#  '250.866 31.749',
#  '39.167 18.163',
#  '92.859 37.876',
#  '222.804 47.323',
#  '122.665 22.206',
#  '222.453 73.141',
#  '144.563 -0.581',
#  '208.614 -47.1',
#  '356.883 41.355',
#  '128.632 -59.16',
#  '44.049 26.925',
#  '241.93 -72.152',
#  '225.054 55.328',
#  '93.601 -58.596',
#  '87.535 18.37',
#  '291.103 36.098',
#  '76.721 12.828',
#  '6.36 24.298',
#  '291.802 -65.4',
#  '221.54 -32.153',
#  '40.384 -39.688',
#  '193.638 63.494',
#  '48.133 46.596',
#  '238.021 27.608',
#  '112.184 -29.209',
#  '142.029 14.569',
#  '206.627 33.285',
#  '271.168 -1.354',
#  '127.244 58.191',
#  '56.35 -66.58',
#  '39.731 -2.384',
#  '171.571 -50.115',
#  '108.133 -60.15',
#  '281.141 59.623',
#  '41.088 35.499',
#  '146.04 63.536',
#  '304.666 51.222',
#  '49.269 -38.058',
#  '13.01 45.102',
#  '249.017 41.897',
#  '40.672 -0.378',
#  '77.163 -82.625',
#  '317.153 -14.412',
#  '27.096 -39.249',
#  '147.423 71.945',
#  '322.636 14.895',
#  '231.171 -79.11',
#  '349.939 -40.111',
#  '286.261 3.899',
#  '86.373 18.904',
#  '201.799 37.599',
#  '228.81 -41.042',
#  '320.177 67.587',
#  '227.231 42.396',
#  '252.972 39.958',
#  '186.071 15.099',
#  '289.366 -15.087',
#  '46.564 -62.662',
#  '276.806 -55.556',
#  '319.172 48.975',
#  '102.942 23.033',
#  '194.365 28.331',
#  '197.276 49.838',
#  '127.001 46.234',
#  '195.31 56.902',
#  '65.439 -51.188',
#  '145.032 -65.826',
#  '290.723 -12.585',
#  '207.592 5.971',
#  '134.86 2.755',
#  '356.975 -79.916',
#  '281.843 -11.188',
#  '184.049 20.225',
#  '252.333 52.733',
#  '209.293 0.607',
#  '344.497 15.448',
#  '30.653 33.48',
#  '253.862 -12.875',
#  '69.521 -34.249',
#  '104.129 41.787',
#  '105.166 -73.136',
#  '124.233 20.237',
#  '81.328 32.488',
#  '145.321 66.762',
#  '326.764 26.215',
#  '37.851 -1.594',
#  '330.999 -17.937',
#  '188.498 27.942',
#  '325.129 58.749',
#  '232.114 37.752',
#  '211.915 1.332',
#  '85.236 -4.401',
#  '67.369 28.879',
#  '301.309 -64.943',
#  '163.722 -14.177',
#  '131.573 -60.181',
#  '344.005 -21.65',
#  '355.305 31.293',
#  '332.714 36.596',
#  '278.937 -12.026',
#  '332.354 -31.761',
#  '69.268 -17.259',
#  '70.973 -63.005',
#  '348.948 -44.645',
#  '29.618 -1.603',
#  '345.074 -5.38',
#  '144.464 44.284',
#  '290.544 -64.599',
#  '98.473 -19.897',
#  '296.108 -2.952',
#  '75.135 -75.701',
#  '253.103 82.036',
#  '8.304 25.557',
#  '135.028 -47.554',
#  '41.186 -26.146',
#  '207.281 -10.353',
#  '341.96 1.294',
#  '47.606 13.999',
#  '215.898 45.602',
#  '192.454 -29.187',
#  '358.635 29.431',
#  '182.426 46.52',
#  '27.94 -3.219',
#  '170.049 -57.527',
#  '197.093 -58.996',
#  '92.387 -13.285',
#  '269.801 -27.616',
#  '35.907 67.525',
#  '220.256 -2.499',
#  '330.79 -65.54',
#  '214.233 -11.124',
#  '230.06 0.624',
#  '260.67 -2.979',
#  '89.038 -11.591',
#  '179.581 63.057',
#  '17.474 0.003',
#  '357.224 36.1',
#  '181.914 -55.706',
#  '184.415 -37.114',
#  '273.128 -9.525',
#  '343.336 82.171',
#  '20.723 -77.784',
#  '274.963 -68.161',
#  '259.771 16.729',
#  '224.414 28.187',
#  '53.776 -40.168',
#  '152.68 24.124',
#  '24.597 41.492',
#  '249.39 29.796',
#  '134.536 -33.477',
#  '250.166 68.225',
#  '172.222 17.063',
#  '86.859 82.91',
#  '24.274 -64.143',
#  '139.405 87.3',
#  '309.282 -24.726',
#  '87.568 14.47',
#  '321.555 -20.148',
#  '355.671 47.478',
#  '283.436 -54.283',
#  '296.278 -7.974',
#  '196.654 18.709',
#  '305.351 34.966',
#  '137.06 17.485',
#  '272.459 -16.32',
#  '138.579 -0.134',
#  '314.9 -22.548',
#  '173.15 27.706',
#  '183.095 54.376',
#  '196.118 59.421',
#  '355.278 9.9',
#  '149.045 13.674',
#  '134.398 -32.363',
#  '91.984 55.732',
#  '157.541 -51.794',
#  '236.438 -0.355',
#  '279.475 -11.682',
#  '116.774 52.037',
#  '58.866 2.036',
#  '67.901 14.67',
#  '43.486 13.387',
#  '147.524 -42.33',
#  '140.387 -58.193',
#  '173.957 15.033',
#  '171.091 48.064',
#  '194.307 59.003',
#  '311.435 49.838',
#  '190.095 -50.588',
#  '168.62 -30.413',
#  '153.708 -62.354',
#  '177.787 78.052',
#  '195.575 30.173',
#  '326.8 -8.232',
#  '256.79 23.942',
#  '13.473 -42.929',
#  '300.589 54.301',
#  '228.519 55.318',
#  '307.334 -11.873',
#  '31.617 7.432',
#  '83.216 54.52',
#  '270.896 -16.951',
#  '170.772 -3.513',
#  '271.903 -2.298',
#  '63.598 -58.839',
#  '70.481 -12.255',
#  '288.82 -1.602',
#  '166.645 -29.105',
#  '260.204 41.123',
#  '276.029 -5.667',
#  '136.606 0.42',
#  '303.781 6.255',
#  '234.758 -20.181',
#  '181.042 -32.762',
#  '213.66 -14.508',
#  '146.4 26.959',
#  '357.966 63.09',
#  '275.735 -59.432',
#  '74.736 -9.323',
#  '235.887 -7.304',
#  '8.31 -26.428',
#  '250.692 -38.377',
#  '282.133 -6.981',
#  '273.976 -52.125',
#  '199.69 62.297',
#  '257.184 -22.735',
#  '241.273 -47.455',
#  '216.536 5.853',
#  '233.951 -28.768',
#  '314.223 53.298',
#  '269.531 -6.733',
#  '44.833 13.762',
#  '13.078 49.936',
#  '137.085 -54.437',
#  '245.193 3.535',
#  '230.489 13.249',
#  '355.412 -46.196',
#  '167.975 -30.625',
#  '169.598 -20.051',
#  '331.71 59.996',
#  '339.353 -29.726',
#  '170.886 8.933',
#  '126.723 -17.598',
#  '214.288 42.144',
#  '197.016 -52.742',
#  '148.692 -49.422',
#  '283.002 -4.258',
#  '136.915 13.974',
#  '235.002 12.883',
#  '54.302 -89.029',
#  '42.458 40.489',
#  '58.057 -17.658',
#  '241.607 -39.322',
#  '246.854 -29.415',
#  '273.906 69.248',
#  '291.081 24.14',
#  '212.517 8.682',
#  '251.812 23.881',
#  '258.551 -13.068',
#  '273.075 14.297',
#  '219.123 79.674',
#  '47.549 28.495',
#  '122.426 29.642',
#  '20.033 -35.796',
#  '40.937 -17.779',
#  '129.862 51.006',
#  '319.764 -25.4626',
#  '30.057 8.79',
#  '300.987 65.413',
#  '43.086 -18.043',
#  '87.781 -24.795',
#  '249.363 -23.963',
#  '120.029 -9.076',
#  '124.862 -7.178',
#  '16.24 33.927',
#  '317.904 57.0358',
#  '66.129 64.05',
#  '276.224 24.713',
#  '76.561 -84.687',
#  '150.063 18.284',
#  '13.158 51.573',
#  '349.582 32.44',
#  '310.442 -68.585',
#  '191.493 -7.173',
#  '14.35 -46.799',
#  '290.215 40.6686',
#  '92.924 -39.504',
#  '336.651 -31.414',
#  '190.485 32.9935',
#  '307.415 -52.722',
#  '276.057 51.461',
#  '154.845 -20.639',
#  '154.746 -46.67',
#  '12.702 23.021',
#  '118.248 -41.588',
#  '129.487 -66.52',
#  '265.691 1.605',
#  '327.111 -10.532',
#  '44.785 57.101',
#  '244.256 -47.435',
#  '108.927 49.663',
#  '275.871 -23.666',
#  '287.029 -38.031',
#  '271.482 -3.88',
#  '153.826 27.474',
#  '60.439 -32.708',
#  '223.315 -19.722',
#  '257.745 36.547',
#  '294.094 36.355',
#  '310.83 -0.713',
#  '164.059 53.817',
#  '343.203 70.298',
#  '317.373 -63.981',
#  '57.322 -44.177',
#  '89.415 80.958',
#  '280.513 -28.536',
#  '286.713 56.07',
#  '24.57 34.578',
#  '237.665 -46.237',
#  '164.668 -23.47',
#  '238.895 40.918',
#  '286.751 6.755',
#  '308.205 74.827',
#  '282.045 61.953',
#  '120.132 45.818',
#  '134.363 56.418',
#  '261.638 -23.426',
#  '132.799 52.211',
#  '112.057 75.1',
#  '320.045 -41.277',
#  '2.164 -37.877',
#  '97.876 24.349',
#  '133.491 13.488',
#  '291.427 67.706',
#  '186.022 15.726',
#  '197.432 61.247',
#  '326.088 -56.774',
#  '356.51 -66.008',
#  '211.691 -51.577',
#  '338.292 -15.278',
#  '279.205 17.537',
#  '157.5 -5.259',
#  '260.877 -15.81',
#  '150.34 -68.329',
#  '345.386 87.586',
#  '42.978 49.278',
#  '69.025 43.716',
#  '13.108 7.778',
#  '22.487 -20.561',
#  '12.54 -10.79',
#  '164.603 67.533',
#  '137.489 88.61',
#  '193.871 28.108',
#  '348.589 5.982',
#  '329.936 26.47',
#  '299.89 41.889',
#  '134.155 47.005',
#  '79.295 64.199',
#  '245.877 7.617',
#  '0.2037 44.5739',
#  '285.939 45.706',
#  '12.259 -34.556',
#  '74.586 -2.527',
#  '241.297 21.905',
#  '167.548 -20.434',
#  '1.955 -16.196',
#  '155.921 -17.645',
#  '172.991 -72.651',
#  '303.193 14.029',
#  '166.39 -16.389',
#  '66.465 -77.261',
#  '317.949 -65.389',
#  '189.607 23.129',
#  '291.377 -35.141',
#  '48.274 -65.99',
#  '328.882 37.06',
#  '223.037 -28.542',
#  '0.672 7.004',
#  '289.25 -17.12',
#  '315.664 65.676',
#  '28.697 55.634',
#  '31.542 14.919',
#  '172.907 -16.185',
#  '48.626 30.97',
#  '27.252 22.751',
#  '20.706 5.848',
#  '351.738 26.568',
#  '22.479 -17.99',
#  '55.283 67.665',
#  '299.846 52.618',
#  '2.482 47.752',
#  '44.051 0.296',
#  '88.753 -15.259',
#  '154.187 -21.417',
#  '290.029 76.955',
#  '166.468 -26.667',
#  '194.569 -11.095',
#  '112.319 -5.857',
#  '133.639 -24.202',
#  '245.693 -56.549',
#  '225.943 -31.653',
#  '15.796 -39.091',
#  '315.309 -51.102',
#  '84.618 -27.012',
#  '177.208 -19.483',
#  '263.534 49.232',
#  '350.617 -66.234',
#  '0.777 -37.913',
#  '230.792 25.623',
#  '6.99 9.397',
#  '328.821 29.17',
#  '169.606 3.617',
#  '76.263 -20.744',
#  '255.575 -35.59',
#  '89.171 -3.461',
#  '299.161 -26.463',
#  '209.453 1.512',
#  '136.471 21.487',
#  '296.09 55.755',
#  '256.358 11.457',
#  '356.826 51.2704',
#  '266.223 15.835',
#  '290.813 -8.257',
#  '98.612 -9.735',
#  '107.599 -56.275',
#  '32.309 -67.992',
#  '163.499 -45.464',
#  '251.953 71.819',
#  '168.373 42.381',
#  '195.504 74.568',
#  '83.467 -7.994',
#  '154.202 -12.555',
#  '154.263 35.524',
#  '124.32 43.464',
#  '349.379 43.37',
#  '356.445 49.492',
#  '47.168 13.175',
#  '141.385 31.74',
#  '96.225 4.793',
#  '299.308 -53.149',
#  '11.28 -1.586',
#  '3.333 -0.817',
#  '247.029 15.539',
#  '55.798 23.243',
#  '29.411 16.881',
#  '0.295 65.68',
#  '203.149 34.086',
#  '36.581 -18.948',
#  '257.751 -36.729',
#  '112.75 -54.092',
#  '309.252 -44.177',
#  '208.723 47.391',
#  '72.622 -72.527',
#  '60.166 -55.954',
#  '276.657 -86.113',
#  '339.24 56.885',
#  '175.727 50.977',
#  '32.191 -57.546',
#  '117.712 -0.645',
#  '343.929 -70.973',
#  '46.31 -38.997',
#  '126.582 25.941',
#  '237.99 15.48',
#  '188.046 61.475',
#  '264.194 -25.219',
#  '100.855 50.235',
#  '108.294 -25.112',
#  '18.435 -50.899',
#  '64.49 -65.943',
#  '239.613 25.586',
#  '225.065 88.571',
#  '353.2 -10.609',
#  '328.665 -0.083',
#  '273.741 10.279',
#  '29.644 41.632',
#  '315.917 64.937',
#  '248.681 72.866',
#  '203.694 -10.335',
#  '251.337 44.837',
#  '152.102 10.006',
#  '70.097 22.525',
#  '93.522 64.081',
#  '289.944 60.728',
#  '154.632 26.616',
#  '237.038 -15.969',
#  '313.455 69.034',
#  '10.987 61.938',
#  '294.008 78.352',
#  '191.194 44.108',
#  '252.07 -36.015',
#  '178.672 7.824',
#  '179.4 26.59',
#  '212.446 24.45',
#  '11.613 -8',
#  '142.317 0.19',
#  '119.957 0.778',
#  '138.246 -11.848',
#  '164.166 14.469',
#  '333.552 -26.598',
#  '241.422 -28.385',
#  '210.672 32.167',
#  '90.573 -52.389',
#  '189.082 32.978',
#  '189.531 16.829',
#  '148.891 18.165',
#  '294.746 40.398',
#  '197.006 -75.615',
#  '225.91 17.224',
#  '269.32 33.407',
#  '209.687 47.015',
#  '34.993 -7.141',
#  '334.956 15.419',
#  '68.979 -12.684',
#  '239.233 35.518',
#  '95.095 -8.963',
#  '350.92 29.762',
#  '198.4 8.086',
#  '284.978 -25.274',
#  '183.545 -48.754',
#  '245.007 -28.647',
#  '231.204 -6.958',
#  '241.764 -31.572',
#  '338.142 26.639',
#  '220.917 -27.848',
#  '92.051 -46.604',
#  '269.105 -32.793',
#  '6.794 -23.503',
#  '49.865 18.478',
#  '32.067 33.436',
#  '251.656 0.067',
#  '302.409 4.744',
#  '128.248 33.107',
#  '37.33 -25.145',
#  '39.477 30.833',
#  '120.478 -69.014',
#  '22.748 -34.095',
#  '15.801 -24.542',
#  '168.231 53.845',
#  '328.082 -33.818',
#  '70.485 -11.263',
#  '228.789 44.427',
#  '233.071 63.514',
#  '20.8 38.123',
#  '332.075 6.858',
#  '323.526 48.714',
#  '89.282 -60.612',
#  '82.572 -43.305',
#  '330.798 -54.711',
#  '100.5 -54.722',
#  '331.178 52.991',
#  '95.836 -0.112',
#  '346.776 -68.179',
#  '121.893 2.305',
#  '245.298 60.466',
#  '27.891 61.352',
#  '226.584 12.409',
#  '230.209 -32.79',
#  '14.582 -43.536',
#  '30.184 -17.627',
#  '220.363 33.548',
#  '279.968 -57.433',
#  '339.963 -40.146',
#  '95.061 -55.176',
#  '265.221 -42.375',
#  '163.632 69.061',
#  '336.289 -57.026',
#  '213.088 -11.491',
#  '17.911 -76.042',
#  '65.741 -25.127',
#  '228.055 -80.54',
#  '301.746 -62.568',
#  '287.663 -18.865',
#  '86.79 51.256',
#  '63.56 25.76',
#  '356.783 0.31',
#  '314.231 -62.433',
#  '328.675 -53.189',
#  '270.729 -32.329',
#  '32.638 64.13',
#  '276.871 1.173',
#  '208.416 -18.572',
#  '121.699 -13.984',
#  '274.461 -6.91',
#  '224.481 -11.709',
#  '188.104 -60.274',
#  '8.259 19.484',
#  '32.627 33.1',
#  '101.822 -63.211',
#  '355.616 -5.424',
#  '313.049 72.278',
#  '45.944 75.481',
#  '237.667 -62.044',
#  '173.806 -7.102',
#  '194.964 15.91',
#  '262.13 4.01',
#  '236.96 20.557',
#  '176.554 68.061',
#  '19.177 -9.239',
#  '268.449 80.143',
#  '20.769 -64.06',
#  '280.179 -54.964',
#  '102.274 50.741',
#  '120.661 -26.146',
#  '3.166 32.564',
#  '329.467 38.961',
#  '286.686 68.803',
#  '165.331 51.682',
#  '26.51 69.469',
#  '326.138 -19.981',
#  '287.301 -27.677',
#  '37.961 -71.297',
#  '84.304 5.078',
#  '169.278 30.607',
#  '80.49 47.523',
#  '277.906 36.516',
#  '177.763 57.162',
#  '99.479 23.982',
#  '259.006 55.393',
#  '217.919 36.3',
#  '206.352 44.08',
#  '155.124 41.701',
#  '220.04 -0.164',
#  '136.629 35.151',
#  '112.019 -70.231',
#  '228.22 -14.697',
#  '177.927 -53.086',
#  '355.941 12.159',
#  '231.145 -22.739',
#  '251.259 13.826',
#  '207.514 7.492',
#  '98.261 62.782',
#  '261.632 -53.19',
#  '105.297 -7.84',
#  '338.974 -64.93',
#  '137.235 41.841',
#  '58.132 -55.959',
#  '220.039 -26.667',
#  '276.576 47.102',
#  '299.839 70.13',
#  '335.026 -63.442',
#  '39.218 28.368',
#  '260.213 -80.884',
#  '48.179 62.524',
#  '6.399 -58.048',
#  '354.163 -31.63',
#  '119.828 21.473',
#  '355.065 31.784',
#  '340.573 23.764',
#  '119.666 32.857',
#  '164.685 53.822',
#  '279.501 33.846',
#  '8.395 61.132',
#  '338.054 66.159',
#  '150.531 45.733',
#  '288.04 -32.385',
#  '151.571 44.303',
#  '335.294 -23.147',
#  '301.857 10.954',
#  '149.707 -59.763',
#  '184.623 -38.294',
#  '0.127 -34.844',
#  '100.968 72.25',
#  '293.923 2.42',
#  '228.737 -24.278',
#  '25.819 -33.484',
#  '8.952 8.822',
#  '189.947 10.747',
#  '203.767 -22.119',
#  '6.761 1.18',
#  '245.057 -59.957',
#  '36.903 -55.517',
#  '328.581 -15.74',
#  '56.296 -39.33',
#  '27.824 -18.61',
#  '33.128 -2.198',
#  '3.144 -28.53',
#  '57.853 28.294',
#  '42.933 30.241',
#  '354.707 66.257',
#  '115.271 -20.281',
#  '323.806 -24.809',
#  '32.096 56.946',
#  '261.716 -8.747',
#  '121.355 37.258',
#  '2.004 -29.756',
#  '6.714 74.315',
#  '283.717 20.648',
#  '242.659 30.26',
#  '121.886 57.588',
#  '193.255 75.005',
#  '254.219 55.289',
#  '277.556 -62.305',
#  '237.874 -78.657',
#  '312.832 -78.382',
#  '347.203 10.711',
#  '328.006 -38.857',
#  '297.695 -32.42',
#  '28.871 -27.603',
#  '121.245 -45.564',
#  '315.709 -31.266',
#  '182.755 39.903',
#  '181.525 40.133',
#  '107.342 1.061',
#  '198.956 16.53',
#  '269.533 -63.799',
#  '65.113 -34.079',
#  '40.337 -66.989',
#  '48.486 -42.95',
#  '148.154 10.44',
#  '120.578 -46.302',
#  '178.988 -13.355',
#  '153.453 43.132',
#  '34.8 68.8',
#  '260.22 69.345',
#  '46.213 -47.376',
#  '197.891 61.942',
#  '36.995 11.728',
#  '33.503 -73.553',
#  '0.934 -52.978',
#  '159.422 -53.202',
#  '352.581 26.823',
#  '105.353 -25.866',
#  '358.254 46.524',
#  '149.26 -35.217',
#  '160.403 -21.152',
#  '144.521 15.613',
#  '105.255 -74.602',
#  '332.079 -74.568',
#  '86.615 64.204',
#  '147.228 -13.188',
#  '323.912 6.872',
#  '336.284 -2.252',
#  '148.394 -17.022',
#  '97.193 46.29',
#  '270.992 -82.239',
#  ...]

# %%
a = np.array(c)

# %%
len(bat.hour)
# Out:
# 1185

# %%
bat['hour'].unique().tolist()
# Out:
# [4,
#  2,
#  16,
#  1,
#  15,
#  3,
#  11,
#  9,
#  14,
#  7,
#  13,
#  18,
#  23,
#  8,
#  20,
#  6,
#  0,
#  12,
#  5,
#  22,
#  21,
#  17,
#  19,
#  10]

# %%
list(map(float, str(c[0]).split('\n')[1].strip()[1:-2].split(',')))
# Out:
# [-0.58718301, 0.78436132, 0.1999836]

# %%
coords = []

for i in range(len(c)):
    co = list(map(float, str(c[i]).split('\n')[1].strip()[1:-2].split(',')))
    coords.append(co)

# %%
x = []
y = []
z = []

for i in coords:
    x.append(i[0])
    y.append(i[1])
    z.append(i[2])
    
bat['x'] = x
bat['y'] = y
bat['z'] = z

# %%
type(bat['hour'].unique().tolist())
# Out:
# list

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import seaborn as sns
from matplotlylib import fig_to_plotly
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot, iplot_mpl

init_notebook_mode(connected=True)

h = list(map(int, bat['hour'].unique().tolist()))
fg = seaborn.FacetGrid(data=bat[['x', 'y', 'z', 'hour']], hue='hour', hue_order=h, aspect=1.61)

trace1 = go.Scatter3d(
    x=bat['x'].tolist(),
    y=bat['y'].tolist(),
    z=bat['z'].tolist(),
    mode='markers',
    marker=dict(
        size=2,
        line=dict(
            #color=,
            colorscale='Viridis',
            width=0.9
        ),
        opacity=0.8
    )
)

data = [trace1]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data, layout=layout)
#iplot(fig, filename='GRB coordinates')

sns.set_style("dark")
#sinplot()

py.iplot_mpl(fig)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-156-7c6a71689cef> in <module>()
#      41 #sinplot()
#      42
# ---> 43 py.iplot_mpl(fig)
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/plotly/plotly.py in iplot_mpl(fig, resize, strip_style, update, **plot_options)
#     263
#     264     """
# --> 265     fig = tools.mpl_to_plotly(fig, resize=resize, strip_style=strip_style)
#     266     if update and isinstance(update, dict):
#     267         fig.update(update)
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/tools.py in mpl_to_plotly(fig, resize, strip_style, verbose)
#     457     if matplotlylib:
#     458         renderer = matplotlylib.PlotlyRenderer()
# --> 459         matplotlylib.Exporter(renderer).run(fig)
#     460         if resize:
#     461             renderer.resize()
#
# ~/anaconda3/lib/python3.6/site-packages/plotly/matplotlylib/mplexporter/exporter.py in run(self, fig)
#      43         # Calling savefig executes the draw() command, putting elements
#      44         # in the correct place.
# ---> 45         fig.savefig(io.BytesIO(), format='png', dpi=fig.dpi)
#      46         if self.close_mpl:
#      47             import matplotlib.pyplot as plt
#
# TypeError: 'NoneType' object is not callable

# %%
#Color code these by hour of detection

# %% [markdown]
# ### K-means clustering of 3d coords and Elbowing to determine optimum number of clusters

# %%
bat
# Out:
#              time                    t_no   bat_ra  bat_dec  hour
# GRB
# 180205A  04:25:29                  808625  126.819   11.536     4
# 180204A  02:36:16                  808483  330.123   30.852     2
# 180115A  04:16:03                  805318   12.040  -15.632     4
# 180113A  02:47:06                  804999   19.211   68.682     2
# 180111A  16:42:06                  804692  149.782   48.254    16
# 180103A  01:08:30                  803066  159.585  -53.555     1
# 180102A  15:49:44                  802999  203.078   62.161    15
# 171222A  16:24:59                  799669  148.273   35.624    16
# 171216A  03:06:59                  797441  212.013  -50.500     3
# 171212A  11:57:21                  796778  293.920   20.597    11
# 171211A  09:27:32                  796469   98.154  -58.689     9
# 171209A  14:46:16                  796100  139.387  -30.523    14
# 171205A  07:20:43                  794972  167.423  -12.599     7
# 171123A  14:14:47                  791922  186.198   32.503    14
# 171120A  13:20:02                  791201  163.774   22.461    13
# 171115A  18:51:20                  790053  278.392    9.118    18
# 171103A  23:10:32                  785850  249.510  -10.206    23
# 171102B  15:20:29                  785510  288.096   22.434    15
# 171027A  08:23:06                  783479   61.683   -2.601     8
# 171020A  23:07:10                  780845   39.260   15.199    23
# 171011A  18:32:47                  778154  236.766  -10.064    18
# 171010B  20:59:24  778019|Ground Analysis   34.123  -54.410    20
# 171007A  11:57:38                  777215  135.635   42.930    11
# 171004A  07:55:32                  776347  139.150   52.684     7
# 171001A  18:25:40                  775553   22.080  -11.928    18
# 170921A  14:28:48                  773509   26.840   30.880    14
# 170912B  06:33:46                  772052  215.464  -61.997     6
# 170912A  01:34:16                  772006  167.386  -54.343     1
# 170906C  07:26:17                  770981  128.659   70.805     7
# 170906B  00:55:46                  770958  232.221  -28.251     0
# ...           ...                     ...      ...      ...   ...
# 050416B  22:35:54                  114797  133.848   11.186    22
# 050416A  11:04:44                  114753  188.485   21.058    11
# 050412   05:44:03                  114485  181.099   -1.193     5
# 050410   12:14:34           114298|114299   89.757   79.605    12
# 050406   15:58:48                  113872   34.410  -50.180    15
# 050401   14:20:15                  113120  247.873    2.185    14
# 050326   09:53:56                  112453    6.871  -71.377     9
# 050319   09:31:18                  111622  154.172   43.581     9
# 050318   15:44:37                  111529   49.695  -46.386    15
# 050315   20:59:43                  111063  306.476  -42.591    20
# 050306   03:33:12                  107547  282.309   -9.152     3
# 050223   03:09:06                  106709  271.394  -62.465     3
# 050219B  21:05:51                  106442   81.306  -57.758    21
# 050219A  12:40:01                  106415  166.416  -40.681    12
# 050215B  02:33:43                  106107  174.463   40.797     2
# 050215A  02:15:29                  106106  348.403   49.328     2
# 050202   03:35:15                  104298  290.584  -38.730     3
# 050128   04:19:55                  103906  219.587  -34.765     4
# 050126   12:00:54                  103780  278.115   42.384    12
# 050124   11:30:03                  103647  192.877   13.039    11
# 050117   12:52:36                  102861  358.479   65.939    12
# 041228   10:49:14                  100970  336.642    5.032    10
# 041226   20:34:19                  100815   79.689   73.329    20
# 041224   20:20:58                  100703   56.192   -6.663    20
# 041223   14:06:18                  100585  100.204  -37.068    14
# 041220   22:58:27                  100433  291.288   60.598    22
# 041219C  20:30:34                 100380*  343.926  -76.744    20
# 041219B  15:38:48                 100367*  167.674  -33.458    15
# 041219A  01:42:18           100307|100319    6.154   62.847     1
# 041217   07:28:25                 100116*  164.793  -17.942     7
#
# [1185 rows x 5 columns]
